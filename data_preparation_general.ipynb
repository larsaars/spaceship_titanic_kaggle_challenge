# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('./datasets/original/train.csv')

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.describe()
# Out:
#                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8514.000000   8512.000000   8510.000000   8485.000000   8510.000000
# mean     28.827930    224.687617    458.077203    173.729169    311.138778
# std      14.489021    666.717663   1611.489240    604.696458   1136.705535
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      19.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      38.000000     47.000000     76.000000     27.000000     59.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8505.000000
# mean     304.854791
# std     1145.717189
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       46.000000
# max    24133.000000

# %%
df['Transported'].sum() / len(df)
# Out:
# 0.5036236051995858

# %%
# make passenger group an extra feature
df['PassengerGroup'] = df['PassengerId'].apply(lambda x: x.split('_')[0])

# %%
len(df['PassengerGroup'].unique())
# Out:
# 6217

# %%
# make cabin deck / num /side extra features 
df['CabinDeck'] = df.loc[~df['Cabin'].isnull(), 'Cabin'].apply(lambda x: x.split('/')[0])
df['CabinNum'] = df.loc[~df['Cabin'].isnull(), 'Cabin'].apply(lambda x: x.split('/')[1])
df['CabinSide'] = df.loc[~df['Cabin'].isnull(), 'Cabin'].apply(lambda x: x.split('/')[2])

# %%
# delete cabin feature
del df['Cabin']

# %%
# make last name a feature
df['LastName'] = df.loc[~df['Name'].isnull(), 'Name'].apply(lambda x: x.split()[-1])

# %%
# encode labels to numeric (keep NaN values)
mask = df.isnull()
df = df.apply(LabelEncoder().fit_transform)
df[mask] = np.nan

# %%
df.describe()
# Out:
#        PassengerId   HomePlanet    CryoSleep  Destination          Age  \
# count  8693.000000  8492.000000  8476.000000  8511.000000  8514.000000
# mean   4346.000000     0.665214     0.358306     1.483492    28.827930
# std    2509.597278     0.798155     0.479531     0.820237    14.489021
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2173.000000     0.000000     0.000000     1.000000    19.000000
# 50%    4346.000000     0.000000     0.000000     2.000000    27.000000
# 75%    6519.000000     1.000000     1.000000     2.000000    38.000000
# max    8692.000000     2.000000     1.000000     2.000000    79.000000
#
#                VIP  RoomService    FoodCourt  ShoppingMall          Spa  \
# count  8490.000000  8512.000000  8510.000000   8485.000000  8510.000000
# mean      0.023439   135.875470   167.475088    109.003771   138.896475
# std       0.151303   291.501842   353.555979    245.181067   298.970780
# ...

# %%
# write to csv
df.to_csv('./datasets/preprocessed/train.csv', index=False)

# %%
# TODO create common features if a group is shared
